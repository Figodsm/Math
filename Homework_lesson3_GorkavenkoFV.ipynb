# %%
"""
Напишите код на Python, реализующий расчет длины вектора, заданного его координатами.
Вектор: (10, 10, 0)
"""

import math  
 
# Запрашиваем координаты X, Y, Z
x = float(input('X = '))
y = float(input('Y = '))
z = float(input('Z = '))
 
# Вычисляем длину вектора
lvec = math.sqrt(x * x + y * y + z * z)
 
# Выводим длину вектора
print('Length = ', lvec)
# Out:
# X = 10
# Y = 10
# Z = 0
# Length =  14.142135623730951

# %%
"""
Напишите код на Python, реализующий построение графиков:
окружности,	
эллипса,
гиперболы.
"""
#Код для окружности

import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
circle = plt.Circle((0.6, 0.5), 0.2, color='g')
ax.add_patch(circle)

#Код для эллипса

from math import pi

u=1.     #x-position of the center
v=0.5    #y-position of the center
a=2.     #radius on the x-axis
b=1.5    #radius on the y-axis

t = np.linspace(0, 2*pi, 100)
plt.plot( u+a*np.cos(t) , v+b*np.sin(t) )
plt.grid(color='lightgray',linestyle='--')
plt.show()

#Код для гиперболы

import decimal

xmin = -20
xmax = 20
dx = 0.1

xlist = np.around(np.arange(xmin, xmax, dx), decimals=4)

ylist = 1 / xlist

plt.plot(xlist, ylist)
plt.show()
# Out:
# C:\Users\Filipp\AppData\Local\Temp/ipykernel_14312/4191401767.py:40: RuntimeWarning: divide by zero encountered in true_divide
#   ylist = 1 / xlist

# %%
"""
Задание (в программе)
Нарисуйте трехмерный график двух параллельных плоскостей.
Нарисуйте трехмерный график двух любых поверхностей второго порядка.

"""
# Две параллельные плоскости

import numpy as np
import matplotlib.pyplot as plt

from pylab import *
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = Axes3D(fig)
X = np.arange(-50, 50, 1)
Y = np.arange(-50, 50, 1)
X, Y = np.meshgrid(X, Y)
Z2 = 0 - 2*X - 3*Y
Z1 = 224 - 2*X - 3*Y
#Z1 = -2*(X+10) - (Y+20) * 3
#ax.plot_wireframe(X, Y, Z1)
ax.plot_surface(X, Y, Z1)
ax.plot_surface(X, Y, Z2)
#ax.scatter(0, 0, 0, "z", 50, "red")
show()

# поверхность второго порядка №1
fig = figure()
ax = Axes3D(fig)
X = np.arange(-50, 50, 1)
Y = np.arange(-50, 50, 1)
X, Y = np.meshgrid(X, Y)
Z = X**2 + Y**2
ax.plot_surface(X, Y, Z)
show()

# поверхность второго порядка №2
fig = figure()
ax = Axes3D(fig)
X = np.arange(-150, 150, 1)
Y = np.arange(-150, 150, 1)
X, Y = np.meshgrid(X, Y)
Z = np.sqrt((X-2)**2 - (Y+1)**2)
ax.plot_surface(X, Y, Z)
show()
# Out:
# C:\Users\Filipp\AppData\Local\Temp/ipykernel_14312/863624891.py:15: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# C:\Users\Filipp\AppData\Local\Temp/ipykernel_14312/863624891.py:30: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# ...

# %%
"""
Нарисуйте график функции: для некоторых (2-3 различных) значений параметров k, a, b
"""
#графики для полинома второй степени
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 301)
print(np.poly([1, 1, 2]))
plt.plot(x, 5*x**2+3*x + 1, label=f'k={5}, a={3}, b={1}')
plt.plot(x, 5*x**2+4*x + 1, label=f'k={5}, a={4}, b={1}')
plt.plot(x, 7*x**2+4*x + 50, label=f'k={7}, a={4}, b={50}')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# [ 1. -4.  5. -2.]

# %%
"""
Докажите, что при ортогональном преобразовании сохраняется расстояние между точками.
"""
import numpy as np

x, y = 2, 5
a = np.pi / 4 
sin_a = np.sin(a)
cos_a = np.cos(a)
x1, y1 = x*sin_a + y*cos_a, x*-sin_a + y*cos_a
line1 = np.round(np.linalg.norm([x, y]), 4)
line2 = np.round(np.linalg.norm([x1, y1]), 4)
print(line1, line2)
print(line1 == line2)

"""
Условия ортогональности линейного преобразования:

a11^2 + a12^2 = 1
a21^2 + a22^2 = 1
a11a12 + a21a22 = 0
a11a22 - a12a21 != 0
"""
a11, a12, a21, a22 = sin_a, cos_a, -sin_a, cos_a

print(f'a11^2 + a12^2 = 1: {np.round(a11**2 + a12**2, 1) == 1.0}')
print(f'a21^2 + a22^2 = 1: {np.round(a21**2 + a22**2, 1) == 1.0}')
print(f'a11*a12 + a21*a22 = 0: {np.round(a11*a12 + a21*a22, 1) == 0.0}')
print(f'a11*a12 + a21*a22 = 0: {np.round(a11*a22 - a12*a21, 1) != 0.0}')

# Из рассчетов следует, что преобразование в приведенном примере является ортогональным, 
# при этом расстояние между точками сохраняется, соответствие условие задачи выполнено.
# Out:
# 5.3852 5.3852
# a11^2 + a12^2 = 1: True
# a21^2 + a22^2 = 1: True
# a11*a12 + a21*a22 = 0: True
# a11*a12 + a21*a22 = 0: True

# %%
"""
Задание (в программе)
Напишите код, который будет переводить полярные координаты в декартовы.
Напишите код, который будет рисовать график окружности в полярных координатах.
Напишите код, который будет рисовать график отрезка прямой линии в полярных координатах.
"""
# R - radius and a - angle in degrees
import numpy as np
import matplotlib.pyplot as plt

def polar_to_cartesian(R, a):
    x = R * np.cos(np.radians(a))
    y = R * np.sin(np.radians(a))
    return x, y
print(polar_to_cartesian(5, 7))

def polar_circle(R=1):
    phi = np.linspace(0, 2 * np.pi, 301)
    r = np.linspace(R, R, 301)
    plt.polar(phi, r, color='blue')
plt.show()
polar_circle()
    
def polar_line(R=1, a=45):
    phi = np.array([np.radians(a), np.radians(a)])
    r = np.array([0, R])
    plt.polar(phi, r)
plt.show()
polar_line(R=5, a=7)
# Out:
# (4.96273075820661, 0.6093467170257374)

# %%
"""
Задание (в программе)
exp(x) + x∙(1 – y) = 1  
y = x2 – 1

Решите систему уравнений и неравенств:
y = x2 – 1
exp(x) + x∙(1 – y)  - 1 > 0
"""
from scipy.optimize import fsolve
def equitations(p):
    x, y = p
    return y - x**2 + 1, np.exp(x) + x*(1-y) - 1

x1, y1 = fsolve(equitations, (0, 0))

print(x1, y1)

# подбор начальной точки для решения уравнения, которая удовлетворяет неравенству
x = 0
while True:
    y = x**2 - 1
    if np.exp(x) + x*(1-y) > 1:
        print(f'x: {x}, y: {y}')
        break
    else:
        x += 1
        
print(np.exp(x) + x*(1-0) - 1 > 0)

# подставим найденную точку для поиска корней уравнения
x2, y2 = fsolve(equitations, (1, 0))

print(x2, y2)
# Out:
# -8.12539509656948e-21 -1.0
# x: 1, y: 0
# True
# 6.518257539454072e-15 -1.000000000000011
